# %% [markdown]
# ### Renaming index and column labels

# %%
import pandas as pd

# %%
summer = pd.read_csv("../Course_Materials_Part1/Video_Lecture_NBs/summer.csv", index_col="Athlete")

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.index[0]
# Out:
# 'HAJOS, Alfred'

# %%
summer.index[0] = 'HAJOS, Alfred'

# Error
# Index is immutable, unless a list is passed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-457cc145cd7b> in <module>
# ----> 1 summer.index[0] = 'HAJOS, Alfred'
#       2
#       3 # Error
#       4 # Index is immutable, unless a list is passed
#
# /opt/anaconda3/envs/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    3907
#    3908     def __setitem__(self, key, value):
# -> 3909         raise TypeError("Index does not support mutable operations")
#    3910
#    3911     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
# This is the work around

summer.rename(mapper = {"HAJOS, Alfred":'HAYOS, Alfred'}, axis="index")
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAYOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.rename(index = {"HAJOS, Alfred":'HAYOS, Alfred'}, inplace=True)

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAYOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.rename(mapper = {"Sex":"Gender", "City":"Host_City"}, axis = "columns")
# Out:
#                            Year Host_City      Sport           Discipline  \
# Athlete
# HAYOS, Alfred              1896    Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896    Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896    Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896    Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896    Athens   Aquatics             Swimming
# ...                         ...       ...        ...                  ...
# JANIKOWSKI, Damian         2012    London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012    London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012    London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012    London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012    London  Wrestling  Wrestling Freestyle
#
# ...

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAYOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.rename(columns = {"Sex":"Gender", "City":"Host_City"}, inplace=True)

# %%
summer
# Out:
#                            Year Host_City      Sport           Discipline  \
# Athlete
# HAYOS, Alfred              1896    Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896    Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896    Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896    Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896    Athens   Aquatics             Swimming
# ...                         ...       ...        ...                  ...
# JANIKOWSKI, Damian         2012    London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012    London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012    London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012    London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012    London  Wrestling  Wrestling Freestyle
#
# ...

# %% [markdown]
# ### Filtering dataframes with on condition

# %%
titanic = pd.read_csv('../Course_Materials_Part1/Video_Lecture_NBs/titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
pd.options.display.max_rows = 900

titanic['sex'] == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27      True
# 28     False
# 29      True
# 30      True
# 31     False
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38     False
# 39     False
# 40     False
# 41     False
# 42      True
# 43     False
# 44     False
# 45      True
# 46      True
# 47     False
# 48      True
# 49     False
# 50      True
# 51      True
# 52     False
# 53     False
# 54      True
# 55      True
# 56     False
# 57      True
# 58     False
# 59      True
# 60      True
# 61     False
# 62      True
# 63      True
# 64      True
# 65      True
# ...

# %%
titanic[titanic['sex'] == 'male']
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck
# 0           0       3  male  22.00      1      0    7.2500        S  NaN
# 4           0       3  male  35.00      0      0    8.0500        S  NaN
# 5           0       3  male    NaN      0      0    8.4583        Q  NaN
# 6           0       1  male  54.00      0      0   51.8625        S    E
# 7           0       3  male   2.00      3      1   21.0750        S  NaN
# 12          0       3  male  20.00      0      0    8.0500        S  NaN
# 13          0       3  male  39.00      1      5   31.2750        S  NaN
# 16          0       3  male   2.00      4      1   29.1250        Q  NaN
# 17          1       2  male    NaN      0      0   13.0000        S  NaN
# 20          0       2  male  35.00      0      0   26.0000        S  NaN
# 21          1       2  male  34.00      0      0   13.0000        S    D
# 23          1       1  male  28.00      0      0   35.5000        S    A
# ...

# %%
titanic.loc[titanic['sex'] == 'male']
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck
# 0           0       3  male  22.00      1      0    7.2500        S  NaN
# 4           0       3  male  35.00      0      0    8.0500        S  NaN
# 5           0       3  male    NaN      0      0    8.4583        Q  NaN
# 6           0       1  male  54.00      0      0   51.8625        S    E
# 7           0       3  male   2.00      3      1   21.0750        S  NaN
# 12          0       3  male  20.00      0      0    8.0500        S  NaN
# 13          0       3  male  39.00      1      5   31.2750        S  NaN
# 16          0       3  male   2.00      4      1   29.1250        Q  NaN
# 17          1       2  male    NaN      0      0   13.0000        S  NaN
# 20          0       2  male  35.00      0      0   26.0000        S  NaN
# 21          1       2  male  34.00      0      0   13.0000        S    D
# 23          1       1  male  28.00      0      0   35.5000        S    A
# ...

# %%
titanic.loc[titanic['sex'] == 'male', 'fare']
# Out:
# 0        7.2500
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 12       8.0500
# 13      31.2750
# 16      29.1250
# 17      13.0000
# 20      26.0000
# 21      13.0000
# 23      35.5000
# 26       7.2250
# 27     263.0000
# 29       7.8958
# 30      27.7208
# 33      10.5000
# 34      82.1708
# 35      52.0000
# 36       7.2292
# 37       8.0500
# 42       7.8958
# 45       8.0500
# 46      15.5000
# 48      21.6792
# 50      39.6875
# 51       7.8000
# 54      61.9792
# 55      35.5000
# 57       7.2292
# 59      46.9000
# 60       7.2292
# 62      83.4750
# 63      27.9000
# 64      27.7208
# 65      15.2458
# 67       8.1583
# 69       8.6625
# 70      10.5000
# 72      73.5000
# 73      14.4542
# 74      56.4958
# 75       7.6500
# 76       7.8958
# 77       8.0500
# 78      29.0000
# 80       9.0000
# 81       9.5000
# 83      47.1000
# 86      34.3750
# 87       8.0500
# 89       8.0500
# 90       8.0500
# 91       7.8542
# 92      61.1750
# ...

# %%
# For readability can do the following:

mask1 = titanic['sex'] == 'male'
mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20      True
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27      True
# 28     False
# 29      True
# 30      True
# 31     False
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38     False
# 39     False
# 40     False
# 41     False
# 42      True
# 43     False
# 44     False
# 45      True
# 46      True
# 47     False
# 48      True
# 49     False
# 50      True
# 51      True
# 52     False
# 53     False
# 54      True
# 55      True
# 56     False
# 57      True
# 58     False
# 59      True
# 60      True
# 61     False
# 62      True
# 63      True
# 64      True
# 65      True
# ...

# %%
titanic_male = titanic.loc[mask1]

# %%
titanic_male.head()
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 0         0       3  male  22.0      1      0   7.2500        S  NaN
# 4         0       3  male  35.0      0      0   8.0500        S  NaN
# 5         0       3  male   NaN      0      0   8.4583        Q  NaN
# 6         0       1  male  54.0      0      0  51.8625        S    E
# 7         0       3  male   2.0      3      1  21.0750        S  NaN

# %%
titanic.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
titanic.dtypes == object
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
mask2 = titanic.dtypes == object
mask2
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
titanic.loc[:, ~mask2]  # Note: ~ (tilda) means NOT
# Out:
#      survived  pclass    age  sibsp  parch      fare
# 0           0       3  22.00      1      0    7.2500
# 1           1       1  38.00      1      0   71.2833
# 2           1       3  26.00      0      0    7.9250
# 3           1       1  35.00      1      0   53.1000
# 4           0       3  35.00      0      0    8.0500
# 5           0       3    NaN      0      0    8.4583
# 6           0       1  54.00      0      0   51.8625
# 7           0       3   2.00      3      1   21.0750
# 8           1       3  27.00      0      2   11.1333
# 9           1       2  14.00      1      0   30.0708
# 10          1       3   4.00      1      1   16.7000
# 11          1       1  58.00      0      0   26.5500
# 12          0       3  20.00      0      0    8.0500
# 13          0       3  39.00      1      5   31.2750
# 14          0       3  14.00      0      0    7.8542
# 15          1       2  55.00      0      0   16.0000
# 16          0       3   2.00      4      1   29.1250
# ...

# %%
titanic.loc[mask1, ~mask2]  # Note: ~ (tilda) means NOT
# Out:
#      survived  pclass    age  sibsp  parch      fare
# 0           0       3  22.00      1      0    7.2500
# 4           0       3  35.00      0      0    8.0500
# 5           0       3    NaN      0      0    8.4583
# 6           0       1  54.00      0      0   51.8625
# 7           0       3   2.00      3      1   21.0750
# 12          0       3  20.00      0      0    8.0500
# 13          0       3  39.00      1      5   31.2750
# 16          0       3   2.00      4      1   29.1250
# 17          1       2    NaN      0      0   13.0000
# 20          0       2  35.00      0      0   26.0000
# 21          1       2  34.00      0      0   13.0000
# 23          1       1  28.00      0      0   35.5000
# 26          0       3    NaN      0      0    7.2250
# 27          0       1  19.00      3      2  263.0000
# 29          0       3    NaN      0      0    7.8958
# 30          0       1  40.00      0      0   27.7208
# 33          0       2  66.00      0      0   10.5000
# ...
