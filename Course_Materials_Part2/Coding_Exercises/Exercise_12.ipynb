# %% [markdown]
# # Coding Exercises (Part 1)

# %% [markdown]
# ## Full Data Workflow A-Z: Merging, Joining, Concatenating

# %% [markdown]
# ### Exercise 12: Merging, joining, aligning and concatenating Data

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Option 1: Self_guided

# %% [markdown]
# ### Concatenating DataFrames vertically

# %% [markdown]
# __Import__ the cars dataset (with cars from usa and europe) from the csv-file __cars_clean.csv__. <br>
# Also __import__ the csv-file __cars_jap.csv__ (with cars from japan) and __concatenate__ both DataFrames __vertically__! <br>
# __Save__ the __concatenated DataFrame__ in the variable __cars_all__! <br>
# Finally, __sort__ cars_all by the model_year from __low to high__!

# %% [markdown]
# ### Left Join

# %% [markdown]
# __Import__ the csv-files __summer.csv__ (as summer) and __dictionary.csv__ (as dic) which contains the __full country name__ for the olympic country codes as well as __population__ and __gdp__ statistics for some countries.<br>
#
# __"Copy and paste"__ the __full country name__, __population__ and __gdp__ from the dic DataFrame __into the summer DataFrame__ with a __Left Join__!<br>
# __Save__ the new merged DataFrame in the variable __summer_new__!<br>
#
# __Inspect__ summer_new and determine the __olympic country codes__ for which the dic DataFrame does __not provide__ any information!

# %% [markdown]
# ### Arithmetic operations between DataFrames / Alignment

# %% [markdown]
# __Import__ the csv-files __ath_2008.csv__ and __ath_2012.csv__ with all medals winners in the Sport __Athletics__ in the Editions __2008__ and __2012__.

# %% [markdown]
# For __all Athletes__ in the two DataFrames, __aggregate/add__ the total number of __Gold__, __Silver__ and __Bronze__ Medals over both editions! __Save__ the aggregated DataFrame in the variable __add__. (Hint: add should contain an index with the Athlete names and three columns, Gold, Silver, Bronze)

# %% [markdown]
# __Sort__ add by Gold, Silver, Bronze from __high to low__! Change datatype to __integer__, if necessary! The first Athlete in your DataFrame should be ... no surprise ... Usain Bolt with 6 Gold and 0 Silver and Bronze Medals.

# %% [markdown]
# -------------------------------------

# %% [markdown]
# ## Option 2: Guided and Instructed

# %% [markdown]
# # STOP HERE, IF YOU WANT TO DO THE EXERCISE ON YOUR OWN!

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#run the cell
import pandas as pd

# %% [markdown]
# ### Concatenating DataFrames vertically

# %%
#run the cell
cars = pd.read_csv("cars_clean.csv")

# %% [markdown]
# __Inspect__ the __cars__ DataFrame!

# %%
#run the cell
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#run the cell
cars.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 308  27.0          4         140.0        86.0    2790          15.6
# 309  44.0          4          97.0        52.0    2130          24.6
# 310  32.0          4         135.0        84.0    2295          11.6
# 311  28.0          4         120.0        79.0    2625          18.6
# 312  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 308          82     usa  ford mustang gl
# 309          82  europe        vw pickup
# 310          82     usa    dodge rampage
# 311          82     usa      ford ranger
# 312          82     usa   chevrolet s-10

# %%
#run the cell
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           313 non-null    float64
#  1   cylinders     313 non-null    int64
#  2   displacement  313 non-null    float64
#  3   horsepower    313 non-null    float64
#  4   weight        313 non-null    int64
#  5   acceleration  313 non-null    float64
#  6   model_year    313 non-null    int64
#  7   origin        313 non-null    object
#  8   name          313 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 22.1+ KB

# %% [markdown]
# __Inspect__ the cars_jap DataFrame!

# %%
#run the cell
cars_jap = pd.read_csv("cars_jap.csv")

# %%
#run the cell
cars_jap.head()
# Out:
#     mpg  cyl   disp    hp  weight   acc  year                   name
# 0  24.0    4  113.0  95.0    2372  15.0    70  toyota corona mark ii
# 1  27.0    4   97.0  88.0    2130  14.5    70           datsun pl510
# 2  27.0    4   97.0  88.0    2130  14.5    71           datsun pl510
# 3  25.0    4  113.0  95.0    2228  14.0    71          toyota corona
# 4  31.0    4   71.0  65.0    1773  19.0    71    toyota corolla 1200

# %% [markdown]
# Before we can concatenate both DataFrames, we need to __align__ them!<br>
# 108. __Insert__ the column __origin__ to __cars_jap__ at the most appropriate position! __Fill in the gaps!__

# %%
cars_jap.insert(loc=7, column='origin', value="japan")

# %%
cars_jap
# Out:
#      mpg  cyl   disp    hp  weight   acc  year origin                   name
# 0   24.0    4  113.0  95.0    2372  15.0    70  japan  toyota corona mark ii
# 1   27.0    4   97.0  88.0    2130  14.5    70  japan           datsun pl510
# 2   27.0    4   97.0  88.0    2130  14.5    71  japan           datsun pl510
# 3   25.0    4  113.0  95.0    2228  14.0    71  japan          toyota corona
# 4   31.0    4   71.0  65.0    1773  19.0    71  japan    toyota corolla 1200
# ..   ...  ...    ...   ...     ...   ...   ...    ...                    ...
# 74  34.0    4  108.0  70.0    2245  16.9    82  japan         toyota corolla
# 75  38.0    4   91.0  67.0    1965  15.0    82  japan            honda civic
# 76  32.0    4   91.0  67.0    1965  15.7    82  japan     honda civic (auto)
# 77  38.0    4   91.0  67.0    1995  16.2    82  japan          datsun 310 gx
# 78  32.0    4  144.0  96.0    2665  13.9    82  japan       toyota celica gt
#
# [79 rows x 9 columns]

# %% [markdown]
# Also the column labels should match. <br>
# 109. __Overwrite__ the column labels in __cars_jap__ and use the same column labels that we have in cars!

# %%
cars_jap.columns = cars.columns

# %% [markdown]
# __Inspect__!

# %%
#run the cell
cars_jap.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  24.0          4         113.0        95.0    2372          15.0
# 1  27.0          4          97.0        88.0    2130          14.5
# 2  27.0          4          97.0        88.0    2130          14.5
# 3  25.0          4         113.0        95.0    2228          14.0
# 4  31.0          4          71.0        65.0    1773          19.0
#
#    model_year origin                   name
# 0          70  japan  toyota corona mark ii
# 1          70  japan           datsun pl510
# 2          71  japan           datsun pl510
# 3          71  japan          toyota corona
# 4          71  japan    toyota corolla 1200

# %% [markdown]
# 110. __Concatenate__ both DataFrames __vertically__ and create a __new RangeIndex__! __Save__ the new DataFrame in the variable __cars_all__!

# %%
cars_all = pd.concat([cars, cars_jap], ignore_index=True)

# %%
pd.options.display.max_rows = 600

cars_all
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 378  32.4          4         108.0        75.0    2350          16.8
# 379  32.9          4         119.0       100.0    2615          14.8
# 380  31.6          4         120.0        74.0    2635          18.3
# 381  25.4          6         168.0       116.0    2900          12.6
# 382  24.2          6         146.0       120.0    2930          13.8
# 383  37.0          4          91.0        68.0    2025          18.2
# 384  31.0          4          91.0        68.0    1970          17.6
# 385  36.0          4         120.0        88.0    2160          14.5
# 386  36.0          4         107.0        75.0    2205          14.5
# 387  34.0          4         108.0        70.0    2245          16.9
# 388  38.0          4          91.0        67.0    1965          15.0
# 389  32.0          4          91.0        67.0    1965          15.7
# 390  38.0          4          91.0        67.0    1995          16.2
# 391  32.0          4         144.0        96.0    2665          13.9
#
#      model_year  origin                                  name
# 0            70     usa             chevrolet chevelle malibu
# 1            70     usa                     buick skylark 320
# 2            70     usa                    plymouth satellite
# 3            70     usa                         amc rebel sst
# 4            70     usa                           ford torino
# 5            70     usa                      ford galaxie 500
# 6            70     usa                      chevrolet impala
# 7            70     usa                     plymouth fury iii
# 8            70     usa                      pontiac catalina
# 9            70     usa                    amc ambassador dpl
# 10           70     usa                   dodge challenger se
# 11           70     usa                    plymouth 'cuda 340
# 12           70     usa                 chevrolet monte carlo
# 13           70     usa               buick estate wagon (sw)
# 14           70     usa                       plymouth duster
# 15           70     usa                            amc hornet
# 16           70     usa                         ford maverick
# 17           70  europe                  vw 1131 deluxe sedan
# 18           70  europe                           peugeot 504
# 19           70  europe                           audi 100 ls
# 20           70  europe                              saab 99e
# 21           70  europe                              bmw 2002
# 22           70     usa                           amc gremlin
# 23           70     usa                             ford f250
# 24           70     usa                         chevrolet c20
# 25           70     usa                            dodge d200
# 26           70     usa                              ih 1200d
# 27           71     usa                   chevrolet vega 2300
# 28           71     usa                           amc gremlin
# 29           71     usa             plymouth satellite custom
# 30           71     usa             chevrolet chevelle malibu
# 31           71     usa                       ford torino 500
# 32           71     usa                           amc matador
# 33           71     usa                      chevrolet impala
# 34           71     usa             pontiac catalina brougham
# 35           71     usa                      ford galaxie 500
# 36           71     usa                     plymouth fury iii
# 37           71     usa                     dodge monaco (sw)
# 38           71     usa              ford country squire (sw)
# 39           71     usa                   pontiac safari (sw)
# 40           71     usa            amc hornet sportabout (sw)
# 41           71     usa                   chevrolet vega (sw)
# 42           71     usa                      pontiac firebird
# 43           71     usa                          ford mustang
# 44           71     usa                    mercury capri 2000
# 45           71  europe                             opel 1900
# 46           71  europe                           peugeot 304
# 47           71  europe                             fiat 124b
# 48           71  europe                          vw model 111
# 49           71     usa                      plymouth cricket
# 50           72     usa                    dodge colt hardtop
# 51           72  europe                             vw type 3
# 52           72     usa                        chevrolet vega
# 53           72     usa                   ford pinto runabout
# 54           72     usa                      chevrolet impala
# 55           72     usa                      pontiac catalina
# 56           72     usa                     plymouth fury iii
# 57           72     usa                      ford galaxie 500
# 58           72     usa                    amc ambassador sst
# 59           72     usa                       mercury marquis
# 60           72     usa                  buick lesabre custom
# 61           72     usa            oldsmobile delta 88 royale
# 62           72     usa                chrysler newport royal
# 63           72     usa                      amc matador (sw)
# 64           72     usa      chevrolet chevelle concours (sw)
# 65           72     usa                 ford gran torino (sw)
# 66           72     usa        plymouth satellite custom (sw)
# 67           72  europe                       volvo 145e (sw)
# 68           72  europe                           vw 411 (sw)
# 69           72  europe                      peugeot 504 (sw)
# 70           72  europe                       renault 12 (sw)
# 71           72     usa                       ford pinto (sw)
# 72           72     usa                       dodge colt (sw)
# 73           73     usa                     buick century 350
# 74           73     usa                           amc matador
# 75           73     usa                      chevrolet malibu
# 76           73     usa                      ford gran torino
# 77           73     usa                  dodge coronet custom
# 78           73     usa              mercury marquis brougham
# 79           73     usa             chevrolet caprice classic
# 80           73     usa                              ford ltd
# 81           73     usa              plymouth fury gran sedan
# 82           73     usa          chrysler new yorker brougham
# 83           73     usa              buick electra 225 custom
# 84           73     usa               amc ambassador brougham
# 85           73     usa                      plymouth valiant
# 86           73     usa                 chevrolet nova custom
# 87           73     usa                            amc hornet
# 88           73     usa                         ford maverick
# 89           73     usa                       plymouth duster
# 90           73  europe                       vw super beetle
# 91           73     usa                      chevrolet impala
# 92           73     usa                          ford country
# 93           73     usa                plymouth custom suburb
# 94           73     usa              oldsmobile vista cruiser
# 95           73     usa                           amc gremlin
# 96           73     usa                        chevrolet vega
# 97           73     usa                            ford pinto
# 98           73     usa                      mercury capri v6
# 99           73  europe                  fiat 124 sport coupe
# 100          73     usa               chevrolet monte carlo s
# 101          73     usa                    pontiac grand prix
# 102          73  europe                              fiat 128
# 103          73  europe                            opel manta
# 104          73  europe                            audi 100ls
# 105          73  europe                           volvo 144ea
# 106          73     usa                     dodge dart custom
# 107          73  europe                             saab 99le
# 108          73     usa                      oldsmobile omega
# 109          74     usa                       plymouth duster
# 110          74     usa                            amc hornet
# 111          74     usa                        chevrolet nova
# 112          74     usa                            ford pinto
# 113          74     usa                        chevrolet vega
# 114          74     usa     chevrolet chevelle malibu classic
# 115          74     usa                           amc matador
# 116          74     usa            plymouth satellite sebring
# 117          74     usa                      ford gran torino
# 118          74     usa              buick century luxus (sw)
# 119          74     usa             dodge coronet custom (sw)
# 120          74     usa                 ford gran torino (sw)
# 121          74     usa                      amc matador (sw)
# 122          74  europe                              audi fox
# 123          74  europe                             vw dasher
# 124          74  europe                            opel manta
# 125          74     usa                            dodge colt
# 126          74  europe                              fiat 128
# 127          74  europe                           fiat 124 tc
# 128          74  europe                             fiat x1.9
# 129          75     usa               plymouth valiant custom
# 130          75     usa                        chevrolet nova
# 131          75     usa                       mercury monarch
# 132          75     usa                         ford maverick
# 133          75     usa                      pontiac catalina
# 134          75     usa                     chevrolet bel air
# 135          75     usa                   plymouth grand fury
# 136          75     usa                              ford ltd
# 137          75     usa                         buick century
# 138          75     usa             chevrolet chevelle malibu
# 139          75     usa                           amc matador
# 140          75     usa                         plymouth fury
# 141          75     usa                         buick skyhawk
# 142          75     usa                   chevrolet monza 2+2
# 143          75     usa                       ford mustang ii
# 144          75     usa                            ford pinto
# 145          75     usa                           amc gremlin
# 146          75     usa                         pontiac astro
# 147          75  europe                             vw dasher
# 148          75     usa                            ford pinto
# 149          75  europe                             vw rabbit
# 150          75     usa                             amc pacer
# 151          75  europe                            audi 100ls
# 152          75  europe                           peugeot 504
# 153          75  europe                           volvo 244dl
# 154          75  europe                             saab 99le
# 155          76  europe                              fiat 131
# 156          76  europe                             opel 1900
# 157          76     usa                      mercury capri ii
# 158          76     usa                            dodge colt
# 159          76  europe                          renault 12tl
# 160          76     usa     chevrolet chevelle malibu classic
# 161          76     usa                dodge coronet brougham
# 162          76     usa                           amc matador
# 163          76     usa                      ford gran torino
# 164          76     usa                      plymouth valiant
# 165          76     usa                        chevrolet nova
# 166          76     usa                         ford maverick
# 167          76     usa                            amc hornet
# 168          76     usa                    chevrolet chevette
# 169          76     usa                       chevrolet woody
# 170          76  europe                             vw rabbit
# 171          76     usa                        dodge aspen se
# 172          76     usa                     ford granada ghia
# 173          76     usa                    pontiac ventura sj
# 174          76     usa                         amc pacer d/l
# 175          76  europe                             vw rabbit
# 176          76     usa                            ford pinto
# 177          76  europe                             volvo 245
# 178          76     usa            plymouth volare premier v8
# 179          76  europe                           peugeot 504
# 180          76  europe                    mercedes-benz 280s
# 181          76     usa                      cadillac seville
# 182          76     usa                         chevrolet c10
# 183          76     usa                             ford f108
# 184          76     usa                            dodge d100
# 185          77     usa               buick opel isuzu deluxe
# 186          77  europe                         renault 5 gtl
# 187          77     usa                     plymouth arrow gs
# 188          77     usa             chevrolet caprice classic
# 189          77     usa            oldsmobile cutlass supreme
# 190          77     usa                 dodge monaco brougham
# 191          77     usa               mercury cougar brougham
# 192          77     usa                    chevrolet concours
# 193          77     usa                         buick skylark
# 194          77     usa                plymouth volare custom
# 195          77     usa                          ford granada
# 196          77     usa                 pontiac grand prix lj
# 197          77     usa          chevrolet monte carlo landau
# 198          77     usa                      chrysler cordoba
# 199          77     usa                      ford thunderbird
# 200          77  europe                      vw rabbit custom
# 201          77     usa                 pontiac sunbird coupe
# 202          77     usa                   ford mustang ii 2+2
# 203          77     usa                    chevrolet chevette
# 204          77     usa                        dodge colt m/m
# 205          77  europe                             vw dasher
# 206          77  europe                              bmw 320i
# 207          78  europe               vw rabbit custom diesel
# 208          78     usa                           ford fiesta
# 209          78     usa     oldsmobile cutlass salon brougham
# 210          78     usa                        dodge diplomat
# 211          78     usa                  mercury monarch ghia
# 212          78     usa                    pontiac phoenix lj
# 213          78     usa                      chevrolet malibu
# 214          78     usa                  ford fairmont (auto)
# 215          78     usa                   ford fairmont (man)
# 216          78     usa                       plymouth volare
# 217          78     usa                           amc concord
# 218          78     usa                 buick century special
# 219          78     usa                        mercury zephyr
# 220          78     usa                           dodge aspen
# 221          78     usa                       amc concord d/l
# 222          78     usa          chevrolet monte carlo landau
# 223          78     usa       buick regal sport coupe (turbo)
# 224          78     usa                           ford futura
# 225          78     usa                       dodge magnum xe
# 226          78     usa                    chevrolet chevette
# 227          78     usa                            dodge omni
# 228          78     usa                      plymouth sapporo
# 229          78     usa                oldsmobile starfire sx
# 230          78  europe                             audi 5000
# 231          78  europe                           volvo 264gl
# 232          78  europe                            saab 99gle
# 233          78  europe                         peugeot 604sl
# 234          78  europe                           vw scirocco
# 235          79     usa                     pontiac lemans v6
# 236          79     usa                      mercury zephyr 6
# 237          79     usa                       ford fairmont 4
# 238          79     usa                      amc concord dl 6
# 239          79     usa                         dodge aspen 6
# 240          79     usa             chevrolet caprice classic
# 241          79     usa                       ford ltd landau
# 242          79     usa                 mercury grand marquis
# 243          79     usa                       dodge st. regis
# 244          79     usa               buick estate wagon (sw)
# 245          79     usa              ford country squire (sw)
# 246          79     usa         chevrolet malibu classic (sw)
# 247          79     usa  chrysler lebaron town @ country (sw)
# 248          79  europe                      vw rabbit custom
# 249          79     usa           dodge colt hatchback custom
# 250          79     usa                         amc spirit dl
# 251          79  europe                    mercedes-benz 300d
# 252          79     usa                     cadillac eldorado
# 253          79  europe                           peugeot 504
# 254          79     usa     oldsmobile cutlass salon brougham
# 255          79     usa                      plymouth horizon
# 256          79     usa                  plymouth horizon tc3
# 257          79  europe                    fiat strada custom
# 258          79     usa                 buick skylark limited
# 259          79     usa                    chevrolet citation
# 260          79     usa             oldsmobile omega brougham
# 261          79     usa                       pontiac phoenix
# 262          80  europe                             vw rabbit
# 263          80     usa                    chevrolet chevette
# 264          80     usa                    chevrolet citation
# 265          80     usa                         ford fairmont
# 266          80     usa                           amc concord
# 267          80     usa                           dodge aspen
# 268          80  europe                             audi 4000
# 269          80     usa                            dodge colt
# 270          80  europe                  vw rabbit c (diesel)
# 271          80  europe                    vw dasher (diesel)
# 272          80  europe                   audi 5000s (diesel)
# 273          80  europe                    mercedes-benz 240d
# 274          80  europe                             vw rabbit
# 275          80  europe                     triumph tr7 coupe
# 276          81     usa                      plymouth reliant
# 277          81     usa                         buick skylark
# 278          81     usa                dodge aries wagon (sw)
# 279          81     usa                    chevrolet citation
# 280          81     usa                      plymouth reliant
# 281          81     usa                        plymouth champ
# 282          81     usa                    plymouth horizon 4
# 283          81     usa                        ford escort 4w
# 284          81     usa                        ford escort 2h
# 285          81  europe                              vw jetta
# 286          81  europe             peugeot 505s turbo diesel
# 287          81  europe                          volvo diesel
# 288          81     usa                         buick century
# 289          81     usa                 oldsmobile cutlass ls
# 290          81     usa                       ford granada gl
# 291          81     usa                chrysler lebaron salon
# 292          82     usa                    chevrolet cavalier
# 293          82     usa              chevrolet cavalier wagon
# 294          82     usa             chevrolet cavalier 2-door
# 295          82     usa            pontiac j2000 se hatchback
# 296          82     usa                        dodge aries se
# 297          82     usa                       pontiac phoenix
# 298          82     usa                  ford fairmont futura
# 299          82  europe                           vw rabbit l
# 300          82     usa                plymouth horizon miser
# 301          82     usa                        mercury lynx l
# 302          82     usa                 buick century limited
# 303          82     usa     oldsmobile cutlass ciera (diesel)
# 304          82     usa            chrysler lebaron medallion
# 305          82     usa                        ford granada l
# 306          82     usa                     dodge charger 2.2
# 307          82     usa                      chevrolet camaro
# 308          82     usa                       ford mustang gl
# 309          82  europe                             vw pickup
# 310          82     usa                         dodge rampage
# 311          82     usa                           ford ranger
# 312          82     usa                        chevrolet s-10
# 313          70   japan                 toyota corona mark ii
# 314          70   japan                          datsun pl510
tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 387  34.0          4         108.0        70.0    2245          16.9
# 388  38.0          4          91.0        67.0    1965          15.0
# 389  32.0          4          91.0        67.0    1965          15.7
# 390  38.0          4          91.0        67.0    1995          16.2
# 391  32.0          4         144.0        96.0    2665          13.9
#
#      model_year origin                name
# 387          82  japan      toyota corolla
# 388          82  japan         honda civic
# 389          82  japan  honda civic (auto)
# 390          82  japan       datsun 310 gx
# 391          82  japan    toyota celica gt

# %% [markdown]
# 111. __Sort cars_all__ by the __model_year__ from __low to high__! Create a __new RangeIndex__ (drop the old)! __Fill in the gaps__!

# %%
cars_all = cars_all.sort_values("model_year", ascending=True).reset_index(drop = True)

# %% [markdown]
# __Inspect__!

# %%
#run the cell
cars_all.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  27.0          4          97.0        88.0    2130          14.5
# 2   9.0          8         304.0       193.0    4732          18.5
# 3  11.0          8         318.0       210.0    4382          13.5
# 4  10.0          8         307.0       200.0    4376          15.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70  japan               datsun pl510
# 2          70    usa                   ih 1200d
# 3          70    usa                 dodge d200
# 4          70    usa              chevrolet c20

# %%
#run the cell
cars_all.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 387  44.0          4          97.0        52.0    2130          24.6
# 388  32.0          4         135.0        84.0    2295          11.6
# 389  28.0          4         120.0        79.0    2625          18.6
# 390  38.0          4          91.0        67.0    1995          16.2
# 391  32.0          4         144.0        96.0    2665          13.9
#
#      model_year  origin              name
# 387          82  europe         vw pickup
# 388          82     usa     dodge rampage
# 389          82     usa       ford ranger
# 390          82   japan     datsun 310 gx
# 391          82   japan  toyota celica gt

# %%
#run the cell
cars_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 27.7+ KB

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# ### Left Join

# %%
# run the cell!
summer = pd.read_csv("summer.csv")

# %% [markdown]
# __Inspect__ the __summer__ DataFrame!

# %%
# run the cell!
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
# run the cell!
dic = pd.read_csv("dictionary.csv")

# %% [markdown]
# __Inspect__ dict!

# %%
# run the cell!
dic.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %% [markdown]
# __dic__ contains the Olympic Games __Country Codes__ ("Code") with the corresponding __full country names__ ("Country") as well as recent __Population__ and __GDP__ statistics.<br>

# %% [markdown]
# 112. __Create__ the columns __Country__, __Population__ and __GDP per Capita__ in the __summer__ DataFrame by using a __Left Join__ with __pd.merge()__. <br>
# __Save__ the merged Dataframe in the variable __summer_new__! __Fill in the gaps__!

# %%
summer_new = pd.merge(summer, dic, how = "left", left_on= 'Country', right_on = 'Code', indicator=True)

# %% [markdown]
# __Inspect__ summer_new!

# %%
# run the cell!
summer_new.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country_x Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred       HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto       AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios       GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis       GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon       GRE    Men
#
#                         Event   Medal Country_y Code  Population  \
# 0              100M Freestyle    Gold   Hungary  HUN   9844686.0
# 1              100M Freestyle  Silver   Austria  AUT   8611088.0
# 2  100M Freestyle For Sailors  Bronze    Greece  GRE  10823732.0
# 3  100M Freestyle For Sailors    Gold    Greece  GRE  10823732.0
# 4  100M Freestyle For Sailors  Silver    Greece  GRE  10823732.0
#
#    GDP per Capita _merge
# 0    12363.543460   both
# 1    43774.985174   both
# 2    18002.230578   both
# 3    18002.230578   both
# 4    18002.230578   both

# %%
# run the cell!
summer_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31165 entries, 0 to 31164
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            31165 non-null  int64
#  1   City            31165 non-null  object
#  2   Sport           31165 non-null  object
#  3   Discipline      31165 non-null  object
#  4   Athlete         31165 non-null  object
#  5   Country_x       31161 non-null  object
#  6   Gender          31165 non-null  object
#  7   Event           31165 non-null  object
#  8   Medal           31165 non-null  object
#  9   Country_y       25742 non-null  object
#  10  Code            25742 non-null  object
#  11  Population      25696 non-null  float64
#  12  GDP per Capita  25142 non-null  float64
#  13  _merge          31165 non-null  category
# dtypes: category(1), float64(2), int64(1), object(10)
# memory usage: 3.4+ MB

# %% [markdown]
# Apparently, __dic__ does __not contain__ additional information for __all olympic country codes__ that are in the __summer__ Dataframe.

# %% [markdown]
# 113. __Filter__ summer_new for the elements in the column __Country_x__, where the __corresponding value__ in the column __Code__ is __missing__! <br>
# __Count__ the frequency! __Fill in the gaps__!

# %%
summer_new.loc[summer_new.Code.isnull(), "Country_x"].value_counts()
# Out:
# URS    2049
# GDR     825
# ROU     640
# FRG     490
# YUG     435
# TCH     329
# EUA     260
# EUN     223
# ZZX      48
# SRB      31
# ANZ      29
# RU1      17
# MNE      14
# TTO      10
# BOH       7
# BWI       5
# SGP       4
# IOP       3
# Name: Country_x, dtype: int64

# %% [markdown]
# For these country codes, we need to find __other sources__ for additional information on the __full country name__, __population__ and __gdp__ (most of these countries do not exist any more.) -> BONUS EXERCISE ;-)

# %% [markdown]
# --------------------------

# %% [markdown]
# ### Arithmetic operations between DataFrames / Alignment

# %%
#run the cell
ath_2008 = pd.read_csv("ath_2008.csv")
ath_2012 = pd.read_csv("ath_2012.csv")

# %% [markdown]
# __Inspect__ the __ath_2008__ DataFrame. It contains all athletes who won medals in __Athletics__ in the Edition __2008__.

# %%
#run the cell
ath_2008.head()
# Out:
#               Athlete  Gold  Silver  Bronze
# 0    ABAKUMOVA, Maria     0       1       0
# 1  ABEYLEGESSE, Elvan     0       2       0
# 2  ALEKNA, Virgilijus     0       0       1
# 3      ALEXEEV, Denis     0       0       1
# 4     ANTONOVA, Olena     0       0       1

# %%
#run the cell
ath_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Athlete  159 non-null    object
#  1   Gold     159 non-null    int64
#  2   Silver   159 non-null    int64
#  3   Bronze   159 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.1+ KB

# %% [markdown]
# __Inspect__ the __ath_2012__ DataFrame. It contains all athletes who won medals in __Athletics__ in the Edition __2012__.

# %%
#run the cell
ath_2012.head()
# Out:
#               Athlete  Gold  Silver  Bronze
# 0      ADAMS, Valerie     1       0       0
# 1  ALLEYNE-FORTE, Ade     0       0       1
# 2         AMOS, Nijel     0       1       0
# 3    ANTYUKH, Natalya     1       1       0
# 4       ASSEFA, Sofia     0       1       0

# %%
#run the cell
ath_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Athlete  171 non-null    object
#  1   Gold     171 non-null    int64
#  2   Silver   171 non-null    int64
#  3   Bronze   171 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.5+ KB

# %% [markdown]
# For __all Athletes__ in the two DataFrames, __aggregate/add__ the total number of __Gold__, __Silver__ and __Bronze__ Medals over both editions! __Save__ the aggregated DataFrame in the variable __add__!

# %% [markdown]
# 114. First, __set__ the __Athlete__ column as the __index__ in both DataFrames! __Save__ the changes!

# %%
ath_2008.set_index('Athlete', inplace=True)

# %%
ath_2008.head()
# Out:
#                     Gold  Silver  Bronze
# Athlete
# ABAKUMOVA, Maria       0       1       0
# ABEYLEGESSE, Elvan     0       2       0
# ALEKNA, Virgilijus     0       0       1
# ALEXEEV, Denis         0       0       1
# ANTONOVA, Olena        0       0       1

# %%
ath_2012.set_index('Athlete', inplace=True)

# %%
ath_2012.head()
# Out:
#                     Gold  Silver  Bronze
# Athlete
# ADAMS, Valerie         1       0       0
# ALLEYNE-FORTE, Ade     0       0       1
# AMOS, Nijel            0       1       0
# ANTYUKH, Natalya       1       1       0
# ASSEFA, Sofia          0       1       0

# %% [markdown]
# 115. __Add__ both DataFrames with the __most appropriate method__! __Save__ the resulting DataFrame in the variable __add__!

# %%
add = ath_2008.add(ath_2012, fill_value=0)

# %% [markdown]
# __Inspect__!

# %%
#run the cell
add.head(10)
# Out:
#                     Gold  Silver  Bronze
# Athlete
# ABAKUMOVA, Maria     0.0     1.0     0.0
# ABEYLEGESSE, Elvan   0.0     2.0     0.0
# ADAMS, Valerie       1.0     0.0     0.0
# ALEKNA, Virgilijus   0.0     0.0     1.0
# ALEXEEV, Denis       0.0     0.0     1.0
# ALLEYNE-FORTE, Ade   0.0     0.0     1.0
# AMOS, Nijel          0.0     1.0     0.0
# ANTONOVA, Olena      0.0     0.0     1.0
# ANTYUKH, Natalya     1.0     1.0     0.0
# ASAHARA, Nobuharu    0.0     0.0     1.0

# %% [markdown]
# 116. __Sort__ the athletes by the number of __Gold__, __Silver__ and __Bronze__ medals from __high to low__!<br>
# __Fill in the gaps!__ Who is the top athlete?

# %%
add = add.sort_values(['Gold', 'Silver', 'Bronze'], ascending = False).astype("int")

# %%
# run the cell!
add.head()
# Out:
#                   Gold  Silver  Bronze
# Athlete
# BOLT, Usain          6       0       0
# FELIX, Allyson       4       1       0
# DIBABA, Tirunesh     3       0       1
# TAYLOR, Angelo       2       1       0
# BEKELE, Kenenisa     2       0       0

# %%
# run the cell!
add.tail()
# Out:
#                          Gold  Silver  Bronze
# Athlete
# WILLIAMS, Novelene          0       0       1
# WILLIAMS-MILLS, Novlene     0       0       1
# YEGO, Alfred Kirwa          0       0       1
# YURCHENKO, Denys            0       0       1
# ZHOU, Chunxiu               0       0       1

# %% [markdown]
# No surprise, it´s Usain Bolt!

# %% [markdown]
# # Well Done!

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 108. insert() method, index pos. 7

# %% [markdown]
# 109. columns attribute

# %% [markdown]
# 110. pd.concat() method, ignore index

# %% [markdown]
# 111. methods sort_values() and reset_index()

# %% [markdown]
# 112. left DataFrame: summer, on "Country" and "Code"

# %% [markdown]
# 113. methods isnull() and value_counts()

# %% [markdown]
# 114. set_index() method

# %% [markdown]
# 115. add() method, fill_value = 0

# %% [markdown]
# 116. pass a list of columns to sort_values() method (sequence matters!)
